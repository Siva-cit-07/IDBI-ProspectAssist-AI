# %%
import pandas as pd

df = pd.read_csv("datasets/train_u6lujuX_CVtuZ9i.csv")

print("Dataset Shape:", df.shape)

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("datasets/train_u6lujuX_CVtuZ9i.csv")
#       5 print("Dataset Shape:", df.shape)
#       7 df.head()
#
# ...

# %%
import os

print("Current Directory:")
print(os.getcwd())
# Out:
# Current Directory:
# C:\Users\Sivaramakrishnan

# %%
import os

print(os.listdir())
# Out:
# ['.anaconda', '.conda', '.continuum', '.copilot', '.gitconfig', '.ipynb_checkpoints', '.ipython', '.jupyter', '.lesshst', '.matplotlib', '.vscode', '.vscode-shared', 'anaconda3', 'AppData', 'Application Data', 'Contacts', 'Cookies', 'Customer-Churn-Prediction', 'Desktop', 'Documents', 'Downloads', 'Favorites', 'IDBI-ProspectAssist-AI', 'Links', 'Local Settings', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{54228ae2-7af5-11f0-a71e-1051073948f1}.TM.blf', 'NTUSER.DAT{54228ae2-7af5-11f0-a71e-1051073948f1}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{54228ae2-7af5-11f0-a71e-1051073948f1}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'ocr_testing.ipynb', 'OneDrive', 'P3.py', 'Pictures', 'PrintHood', 'ProspectAssistAI', 'PyCharmMiscProject', 'PycharmProjects', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'Templates', 'Untitled.ipynb', 'Untitled1.py', 'Videos']

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\Sivaramakrishnan\IDBI-ProspectAssist-AI\datasets\train_u6lujuX_CVtuZ9i.csv"
)

print(df.shape)
df.head()
# Out:
# (614, 13)
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
import os

os.chdir(r"C:\Users\Sivaramakrishnan\IDBI-ProspectAssist-AI")

print(os.getcwd())
# Out:
# C:\Users\Sivaramakrishnan\IDBI-ProspectAssist-AI

# %%
import pandas as pd

df = pd.read_csv("datasets/train_u6lujuX_CVtuZ9i.csv")

print(df.shape)
# Out:
# (614, 13)

# %%
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

print("Tesseract Connected Successfully!")
# Out:
# Tesseract Connected Successfully!

# %%
from PIL import Image
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

img = Image.new("RGB", (400, 100), color="white")

print("OCR Ready")
# Out:
# OCR Ready
